# %% [markdown]
# # Dynamic Pricing Optimization
#
# Search candidate prices for the largest revenue in a simple demand model.
#
# ## What to look for
#
# Demand falls as price rises; revenue peaks at an intermediate price.
#
# This notebook uses the same small example as `main.py`. The chart preview below is embedded so it appears as soon as you open the notebook. Run the code cell to recalculate the printed results and interactive Matplotlib figure (requires NumPy and Matplotlib).

# %%
"""Grid search for the best price in a simple demand model."""
import numpy as np
import matplotlib.pyplot as plt
prices=np.linspace(0,100,201); demand=np.maximum(120-1.1*prices,0); revenue=prices*demand; best=np.argmax(revenue)
print(f"Best grid price: ${prices[best]:.2f}; estimated demand: {demand[best]:.1f}; revenue: ${revenue[best]:.2f}")
fig,ax1=plt.subplots(); ax1.plot(prices,demand,color="steelblue"); ax1.set_xlabel("Price ($)"); ax1.set_ylabel("Demand (units)",color="steelblue")
ax2=ax1.twinx(); ax2.plot(prices,revenue,color="darkorange"); ax2.set_ylabel("Revenue ($)",color="darkorange"); ax2.scatter(prices[best],revenue[best],color="tomato")
ax1.axvline(prices[best],color="gray",linestyle=":"); plt.title("Simple price and revenue model")
fig.tight_layout(); plt.show()

# %% [markdown]
# ## Visualization preview
#
# The saved preview below illustrates the project's main idea. Re-run the code cell above to generate the chart from the example data.

# %%
# This cell displays the chart preview saved in the notebook.
